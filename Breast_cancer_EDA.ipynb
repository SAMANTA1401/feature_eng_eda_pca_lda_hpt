# %% [markdown]
# ### Exploratory Data Analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('breast_cancer.csv')

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension     target
# 0          0.4601                  0.11890  Malignant
# 1          0.2750                  0.08902  Malignant
# 2          0.3613                  0.08758  Malignant
# 3          0.6638                  0.17300  Malignant
# 4          0.2364                  0.07678  Malignant
#
# [5 rows x 31 columns]

# %%
df['target'].value_counts()
# Out:
# target
# Benign       357
# Malignant    212
# Name: count, dtype: int64

# %%
columns = df.columns

# %%
plt.figure(figsize=(8, 6))
sns.countplot(df['target'])
plt.xlabel("Diagnosis")
plt.title("Count Plot of Diagnosis")
# Out:
# Text(0.5, 1.0, 'Count Plot of Diagnosis')

# %% [markdown]
# Distribution of features
# Now I will take a look at the distribution of each feature and see how they are different between 'benign' and 'malignant'. To see the distribution of multiple variables, we can use violin plot, swarm plot or box plot. Let's try each of these plots.

# %%
y = df['target']

# %%
y = pd.DataFrame(y)

# %%
y
# Out:
#         target
# 0    Malignant
# 1    Malignant
# 2    Malignant
# 3    Malignant
# 4    Malignant
# ..         ...
# 564  Malignant
# 565  Malignant
# 566  Malignant
# 567  Malignant
# 568     Benign
#
# [569 rows x 1 columns]

# %%
X = df.drop(columns=['target'])

# %%
X = pd.DataFrame(X)

# %%
X
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 0                   0.07871  ...        25.380          17.33
# 1                   0.05667  ...        24.990          23.41
# 2                   0.05999  ...        23.570          25.53
# 3                   0.09744  ...        14.910          26.50
# 4                   0.05883  ...        22.540          16.67
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 0             184.60      2019.0           0.16220            0.66560
# 1             158.80      1956.0           0.12380            0.18660
# 2             152.50      1709.0           0.14440            0.42450
# 3              98.87       567.7           0.20980            0.86630
# 4             152.20      1575.0           0.13740            0.20500
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      worst concavity  worst concave points  worst symmetry  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      worst fractal dimension
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 30 columns]

# %%
print(X.columns)
# Out:
# Index(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
X = pd.DataFrame(X, columns=columns[:-1])

# %%
X
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0       1.097064     -2.073335        1.269934   0.984375         1.568466
# 1       1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2       1.579888      0.456187        1.566503   1.558884         0.942210
# 3      -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4       1.750297     -1.151816        1.776573   1.826229         0.280372
# ..           ...           ...             ...        ...              ...
# 564     2.110995      0.721473        2.060786   2.343856         1.041842
# 565     1.704854      2.085134        1.615931   1.723842         0.102458
# 566     0.702284      2.045574        0.672676   0.577953        -0.840484
# 567     1.838341      2.336457        1.982524   1.735218         1.525767
# 568    -1.808401      1.221792       -1.814389  -1.347789        -3.112085
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0            3.283515        2.652874             2.532475       2.217515
# 1           -0.487072       -0.023846             0.548144       0.001392
# 2            1.052926        1.363478             2.037231       0.939685
# 3            3.402909        1.915897             1.451707       2.867383
# 4            0.539340        1.371011             1.428493      -0.009560
# ..                ...             ...                  ...            ...
# 564          0.219060        1.947285             2.320965      -0.312589
# 565         -0.017833        0.693043             1.263669      -0.217664
# 566         -0.038680        0.046588             0.105777      -0.809117
# 567          3.272144        3.296944             2.658866       2.137194
# 568         -1.150752       -1.114873            -1.261820      -0.820070
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 0                  2.255747  ...      1.886690      -1.359293
# 1                 -0.868652  ...      1.805927      -0.369203
# 2                 -0.398008  ...      1.511870      -0.023974
# 3                  4.910919  ...     -0.281464       0.133984
# 4                 -0.562450  ...      1.298575      -1.466770
# ..                      ...  ...           ...            ...
# 564               -0.931027  ...      1.901185       0.117700
# 565               -1.058611  ...      1.536720       2.047399
# 566               -0.895587  ...      0.561361       1.374854
# 567                1.043695  ...      1.961239       2.237926
# 568               -0.561032  ...     -1.410893       0.764190
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 0           2.303601    2.001237          1.307686           2.616665
# 1           1.535126    1.890489         -0.375612          -0.430444
# 2           1.347475    1.456285          0.527407           1.082932
# 3          -0.249939   -0.550021          3.394275           3.893397
# 4           1.338539    1.220724          0.220556          -0.313395
# ..               ...         ...               ...                ...
# 564         1.752563    2.015301          0.378365          -0.273318
# 565         1.421940    1.494959         -0.691230          -0.394820
# 566         0.579001    0.427906         -0.809587           0.350735
# 567         2.303601    1.653171          1.430427           3.904848
# 568        -1.432735   -1.075813         -1.859019          -1.207552
#
#      worst concavity  worst concave points  worst symmetry  \
# 0           2.109526              2.296076        2.750622
# 1          -0.146749              1.087084       -0.243890
# 2           0.854974              1.955000        1.152255
# 3           1.989588              2.175786        6.046041
# 4           0.613179              0.729259       -0.868353
# ..               ...                   ...             ...
# 564         0.664512              1.629151       -1.360158
# 565         0.236573              0.733827       -0.531855
# 566         0.326767              0.414069       -1.104549
# 567         3.197605              2.289985        1.919083
# 568        -1.305831             -1.745063       -0.048138
#
#      worst fractal dimension
# 0                   1.937015
# 1                   0.281190
# 2                   0.201391
# 3                   4.935010
# 4                  -0.397100
# ..                       ...
# 564                -0.709091
# 565                -0.973978
# 566                -0.318409
# 567                 2.219635
# 568                -0.751207
#
# [569 rows x 30 columns]

# %%
df_sclaled = pd.concat([X,y],axis=1)

# %%
df_sclaled
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0       1.097064     -2.073335        1.269934   0.984375         1.568466
# 1       1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2       1.579888      0.456187        1.566503   1.558884         0.942210
# 3      -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4       1.750297     -1.151816        1.776573   1.826229         0.280372
# ..           ...           ...             ...        ...              ...
# 564     2.110995      0.721473        2.060786   2.343856         1.041842
# 565     1.704854      2.085134        1.615931   1.723842         0.102458
# 566     0.702284      2.045574        0.672676   0.577953        -0.840484
# 567     1.838341      2.336457        1.982524   1.735218         1.525767
# 568    -1.808401      1.221792       -1.814389  -1.347789        -3.112085
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0            3.283515        2.652874             2.532475       2.217515
# 1           -0.487072       -0.023846             0.548144       0.001392
# 2            1.052926        1.363478             2.037231       0.939685
# 3            3.402909        1.915897             1.451707       2.867383
# 4            0.539340        1.371011             1.428493      -0.009560
# ..                ...             ...                  ...            ...
# 564          0.219060        1.947285             2.320965      -0.312589
# 565         -0.017833        0.693043             1.263669      -0.217664
# 566         -0.038680        0.046588             0.105777      -0.809117
# 567          3.272144        3.296944             2.658866       2.137194
# 568         -1.150752       -1.114873            -1.261820      -0.820070
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                  2.255747  ...      -1.359293         2.303601    2.001237
# 1                 -0.868652  ...      -0.369203         1.535126    1.890489
# 2                 -0.398008  ...      -0.023974         1.347475    1.456285
# 3                  4.910919  ...       0.133984        -0.249939   -0.550021
# 4                 -0.562450  ...      -1.466770         1.338539    1.220724
# ..                      ...  ...            ...              ...         ...
# 564               -0.931027  ...       0.117700         1.752563    2.015301
# 565               -1.058611  ...       2.047399         1.421940    1.494959
# 566               -0.895587  ...       1.374854         0.579001    0.427906
# 567                1.043695  ...       2.237926         2.303601    1.653171
# 568               -0.561032  ...       0.764190        -1.432735   -1.075813
#
#      worst smoothness  worst compactness  worst concavity  \
# 0            1.307686           2.616665         2.109526
# 1           -0.375612          -0.430444        -0.146749
# 2            0.527407           1.082932         0.854974
# 3            3.394275           3.893397         1.989588
# 4            0.220556          -0.313395         0.613179
# ..                ...                ...              ...
# 564          0.378365          -0.273318         0.664512
# 565         -0.691230          -0.394820         0.236573
# 566         -0.809587           0.350735         0.326767
# 567          1.430427           3.904848         3.197605
# 568         -1.859019          -1.207552        -1.305831
#
#      worst concave points  worst symmetry  worst fractal dimension     target
# 0                2.296076        2.750622                 1.937015  Malignant
# 1                1.087084       -0.243890                 0.281190  Malignant
# 2                1.955000        1.152255                 0.201391  Malignant
# 3                2.175786        6.046041                 4.935010  Malignant
# 4                0.729259       -0.868353                -0.397100  Malignant
# ..                    ...             ...                      ...        ...
# 564              1.629151       -1.360158                -0.709091  Malignant
# 565              0.733827       -0.531855                -0.973978  Malignant
# 566              0.414069       -1.104549                -0.318409  Malignant
# 567              2.289985        1.919083                 2.219635  Malignant
# 568             -1.745063       -0.048138                -0.751207     Benign
#
# [569 rows x 31 columns]

# %% [markdown]
# Then I "unpivot" the dataframe from wide format to long format using pd.melt function:

# %%
df_scaled_melt = pd.melt(df_sclaled, id_vars='target',
                         var_name='features', value_name='value')
df_scaled_melt.head(20)
# Out:
#        target     features     value
# 0   Malignant  mean radius  1.097064
# 1   Malignant  mean radius  1.829821
# 2   Malignant  mean radius  1.579888
# 3   Malignant  mean radius -0.768909
# 4   Malignant  mean radius  1.750297
# 5   Malignant  mean radius -0.476375
# 6   Malignant  mean radius  1.170908
# 7   Malignant  mean radius -0.118517
# 8   Malignant  mean radius -0.320167
# 9   Malignant  mean radius -0.473535
# 10  Malignant  mean radius  0.537556
# 11  Malignant  mean radius  0.469393
# 12  Malignant  mean radius  1.432201
# 13  Malignant  mean radius  0.489274
# 14  Malignant  mean radius -0.112836
# 15  Malignant  mean radius  0.117215
# 16  Malignant  mean radius  0.156977
# 17  Malignant  mean radius  0.568798
# 18  Malignant  mean radius  1.613970
# 19     Benign  mean radius -0.166799

# %% [markdown]
# There are 30 features so I will create a violin plot, a swarm plot and a box plot for each batch of 10 features:

# %%
def violin_plot(features, name):
    """
    This function creates violin plots of features given in the argument.
    """
    # create query
    query = ''
    for x in features:
        query += "features =='" + str(x) + "' or "
        print(query)
    query = query[:-4]  # remove the last " or "
    print(query)
    # Create data for visualization
    data = df_scaled_melt.query(query)
    print(data)
     # Plot figure
    plt.figure(figsize=(12, 6))
    sns.violinplot(x='features',
                   y='value',
                   hue='target',
                   data=data,
                   split=True,
                   inner="quart")
    plt.xticks(rotation=45)
    plt.title(name)
    plt.xlabel("Features")
    plt.ylabel("Standardize Value")

# %%
violin_plot(df.columns[0:10], "Violin Plot of the First 10 Features")
# Out:
# features =='mean radius' or
# features =='mean radius' or features =='mean texture' or
# features =='mean radius' or features =='mean texture' or features =='mean perimeter' or
# features =='mean radius' or features =='mean texture' or features =='mean perimeter' or features =='mean area' or
# features =='mean radius' or features =='mean texture' or features =='mean perimeter' or features =='mean area' or features =='mean smoothness' or
# features =='mean radius' or features =='mean texture' or features =='mean perimeter' or features =='mean area' or features =='mean smoothness' or features =='mean compactness' or
# features =='mean radius' or features =='mean texture' or features =='mean perimeter' or features =='mean area' or features =='mean smoothness' or features =='mean compactness' or features =='mean concavity' or
# features =='mean radius' or features =='mean texture' or features =='mean perimeter' or features =='mean area' or features =='mean smoothness' or features =='mean compactness' or features =='mean concavity' or features =='mean concave points' or
# features =='mean radius' or features =='mean texture' or features =='mean perimeter' or features =='mean area' or features =='mean smoothness' or features =='mean compactness' or features =='mean concavity' or features =='mean concave points' or features =='mean symmetry' or
# features =='mean radius' or features =='mean texture' or features =='mean perimeter' or features =='mean area' or features =='mean smoothness' or features =='mean compactness' or features =='mean concavity' or features =='mean concave points' or features =='mean symmetry' or features =='mean fractal dimension' or
# features =='mean radius' or features =='mean texture' or features =='mean perimeter' or features =='mean area' or features =='mean smoothness' or features =='mean compactness' or features =='mean concavity' or features =='mean concave points' or features =='mean symmetry' or features =='mean fractal dimension'
#          target                features     value
# 0     Malignant             mean radius  1.097064
# 1     Malignant             mean radius  1.829821
# 2     Malignant             mean radius  1.579888
# 3     Malignant             mean radius -0.768909
# 4     Malignant             mean radius  1.750297
# ...         ...                     ...       ...
# 5685  Malignant  mean fractal dimension -0.931027
# 5686  Malignant  mean fractal dimension -1.058611
# 5687  Malignant  mean fractal dimension -0.895587
# 5688  Malignant  mean fractal dimension  1.043695
# 5689     Benign  mean fractal dimension -0.561032
#
# [5690 rows x 3 columns]

# %% [markdown]
# Correlation
# As discussed above, some dependent variables in the dataset might be highly correlated with each other. Let's explore the correlation of three examples above.

# %%
def correlation(var):
    """
    1. Print correlation
    2. Create jointplot
    """
    # Print correlation
    print("Correlation: ", df[[var[0], var[1]]].corr())
    print("Correlation: ", df[[var[0], var[1]]].corr().iloc[1, 0])
    # Create jointplot
    plt.figure(figsize=(6, 6))
    sns.jointplot(x=var[0],y= var[1], data=df, kind='reg')

# %%
correlation(['mean perimeter', 'mean area'])
# Out:
# Correlation:                  mean perimeter  mean area
# mean perimeter        1.000000   0.986507
# mean area             0.986507   1.000000
# Correlation:  0.9865068039913907

# %%
correlation(['mean concavity', 'mean concave points'])
# Out:
# Correlation:                       mean concavity  mean concave points
# mean concavity             1.000000             0.921391
# mean concave points        0.921391             1.000000
# Correlation:  0.9213910263788588

# %%
correlation(['worst symmetry', 'worst fractal dimension'])
# Out:
# Correlation:                           worst symmetry  worst fractal dimension
# worst symmetry                 1.000000                 0.537848
# worst fractal dimension        0.537848                 1.000000
# Correlation:  0.537848206253609

# %%
sns.pairplot(df, vars=X.columns[:5], hue="target")
plt.show()

# %% [markdown]
# Two pairs of 3 examples are actually highly correlated. Let's create a heat map to see the overall picture on correlation.

# %%
# Create correlation matrix
corr_mat = X.corr()

# Create mask
mask = np.zeros_like(corr_mat, dtype=np.bool)
mask[np.triu_indices_from(mask, k=1)] = True

# Plot heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(corr_mat, annot=True, fmt='.1f',
            cmap='RdBu_r', vmin=-1, vmax=1,
            mask=mask)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(corr_mat[corr_mat > 0.8], annot=True,
            fmt='.1f', cmap=sns.cubehelix_palette(200), mask=mask)
# Out:
# <Axes: >
